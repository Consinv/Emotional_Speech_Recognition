# %% [markdown]
# ### Load Package

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import librosa
from librosa.display import *
from librosa.effects import *

import os

# %% [markdown]
# ### Preprocessing

# %%
os.chdir("/Users/hyunwoogu/Dropbox/2018MARG/Emotion Recognition/Dataset/RAVDESS")

# %%
Happy = "03-01-03-{0[0]:02d}-{0[1]:02d}-{0[2]:02d}-{0[3]:02d}.wav"
Sad   = "03-01-04-{0[0]:02d}-{0[1]:02d}-{0[2]:02d}-{0[3]:02d}.wav"

Happy_train = np.zeros([128, 44])
Sad_train   = np.zeros([128, 44])

k = [(1, 1, 1), (1, 1, 2), (1, 2, 1), (1, 2, 2), (2, 1, 1), (2, 1, 2), (2, 2, 1), (2, 2, 2)]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
        
fig.show()
fig.canvas.draw()

for i in k:
    for j in range(1, 25):
        index = (i, j)
        index = index[0] + (index[1],)
        
        files    = Happy.format(index)
        data, fs = librosa.load(files)

        n    = data.size

        EffectiveInx= np.argwhere(data > 0.001)
        Effective   = data[EffectiveInx]
        n           = Effective.size
        Effective   = np.reshape(Effective, [n])
        
        Effective_stretch = librosa.effects.time_stretch(Effective, n / fs)
        S = librosa.feature.melspectrogram(Effective_stretch, sr=fs, n_mels=128)
        log_S = librosa.logamplitude(S, ref_power=np.max)
        log_S = log_S[:, range(44)]
        
        ax.clear()
        specshow(log_S, sr=fs, x_axis='time', y_axis='mel')
        fig.canvas.draw()
        plt.tight_layout()
                
        Happy_train = np.vstack((Happy_train, log_S))

Happy_train = np.reshape(Happy_train, [24*8+1, 128, 44])
Happy_train = Happy_train[1:, :, :]
# Out:
# <div id='c0c0a609-5ee2-4dd4-9f81-02a930469487'></div>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
        
fig.show()
fig.canvas.draw()

for i in k:
    for j in range(1, 25):
        index = (i, j)
        index = index[0] + (index[1],)
        
        files    = Happy.format(index)
        data, fs = librosa.load(files)

        n    = data.size

        EffectiveInx= np.argwhere(data > 0.001)
        Effective   = data[EffectiveInx]
        n           = Effective.size
        Effective   = np.reshape(Effective, [n])
        
        Effective_stretch = librosa.effects.time_stretch(Effective, n / fs)
        S = librosa.feature.melspectrogram(Effective_stretch, sr=fs, n_mels=128)
        log_S = librosa.logamplitude(S, ref_power=np.max)
        log_S = log_S[:, range(44)]
        
        ax.clear()
        specshow(log_S, sr=fs, x_axis='time', y_axis='mel')
        fig.canvas.draw()
        plt.tight_layout()
                
        Happy_train = np.vstack((Happy_train, log_S))

Happy_train = np.reshape(Happy_train, [24*8+1, 128, 44])
Happy_train = Happy_train[1:, :, :]

# %%
xTrain = np.vstack((Happy_train, Sad_train))
xTrain = np.reshape(xTrain, [384, 128, 44])
yTrain = np.repeat(np.array([1, 0]), 192)

# %%
inx = np.array(range(384))
np.random.shuffle(inx)
trainInx=inx[0:284]
testInx =inx[284:384]

# %%
x_train = xTrain[trainInx, :, :]
y_train = yTrain[trainInx]

x_test  = xTrain[testInx, :, :]
y_test = yTrain[testInx]

# %% [markdown]
# ### Model

# %%
os.chdir("/Users/hyunwoogu/Dropbox/2018MARG/Emotion Recognition/Emotional Speech Recognition/pitch_detection")

# %%
from keras.datasets import fashion_mnist
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.optimizers import adam
from scipy.misc import toimage #(*)
import matplotlib.pylab as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /Users/hyunwoogu/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
batch_size = 4
epoch = 200
num_classes = 2

# %%
im = x_test[6]
plt.imshow(im, cmap=plt.get_cmap('gray'))
plt.show()

# %%
x_train_RS = x_train.reshape(284, 128, 44, 1)
x_test_RS  = x_test.reshape(100, 128, 44, 1)

x_train_RS = x_train_RS.astype('float32')
x_test_RS  = x_test_RS.astype('float32')

x_train_RS /= 80
x_test_RS  /= 80

y_train_RS = to_categorical(y_train, num_classes)
y_test_RS  = to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(4, 4), activation='relu', input_shape=(128, 44, 1)))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(64, kernel_size=(4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 125, 41, 32)       544
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 20, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 59, 17, 64)        32832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 8, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14848)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1900672
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 1,934,306
# Trainable params: 1,934,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model.fit(x_train_RS, y_train_RS, 
          batch_size=batch_size, epochs=epoch, verbose=1, 
          validation_data=(x_test_RS, y_test_RS))
loss, accuracy = model.evaluate(x_test_RS, y_test_RS, verbose=0)
# Out:
# Train on 284 samples, validate on 100 samples
# Epoch 1/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.6926 - acc: 0.5176 - val_loss: 0.6948 - val_acc: 0.4500
# Epoch 2/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.6961 - acc: 0.5176 - val_loss: 0.6950 - val_acc: 0.4500
# Epoch 3/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.6943 - acc: 0.5176 - val_loss: 0.6896 - val_acc: 0.4500
# Epoch 4/200
# 284/284 [==============================] - 3s 11ms/step - loss: 0.6926 - acc: 0.5634 - val_loss: 0.7235 - val_acc: 0.4500
# Epoch 5/200
# 284/284 [==============================] - 3s 11ms/step - loss: 0.6717 - acc: 0.6408 - val_loss: 0.6245 - val_acc: 0.6800
# Epoch 6/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.6563 - acc: 0.5634 - val_loss: 0.6242 - val_acc: 0.6800
# Epoch 7/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.5944 - acc: 0.7148 - val_loss: 0.5609 - val_acc: 0.7300
# Epoch 8/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.5824 - acc: 0.7042 - val_loss: 0.5390 - val_acc: 0.7600
# Epoch 9/200
# 284/284 [==============================] - 3s 11ms/step - loss: 0.5499 - acc: 0.7394 - val_loss: 0.4994 - val_acc: 0.7800
# Epoch 10/200
# 284/284 [==============================] - 3s 11ms/step - loss: 0.5450 - acc: 0.7218 - val_loss: 0.4988 - val_acc: 0.8000
# Epoch 11/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.4933 - acc: 0.7711 - val_loss: 0.4746 - val_acc: 0.7900
# Epoch 12/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.5215 - acc: 0.7535 - val_loss: 0.5018 - val_acc: 0.7800
# Epoch 13/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.4769 - acc: 0.7852 - val_loss: 0.4532 - val_acc: 0.8100
# Epoch 14/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.4630 - acc: 0.7887 - val_loss: 0.4691 - val_acc: 0.8000
# Epoch 15/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.4457 - acc: 0.8063 - val_loss: 0.4935 - val_acc: 0.7700
# Epoch 16/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.3593 - acc: 0.8592 - val_loss: 0.5105 - val_acc: 0.7700
# Epoch 17/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.3406 - acc: 0.8521 - val_loss: 0.6808 - val_acc: 0.6500
# Epoch 18/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.2974 - acc: 0.8732 - val_loss: 0.6689 - val_acc: 0.6800
# Epoch 19/200
# 284/284 [==============================] - 4s 13ms/step - loss: 0.2608 - acc: 0.8768 - val_loss: 0.6627 - val_acc: 0.7400
# Epoch 20/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.2070 - acc: 0.9261 - val_loss: 0.6551 - val_acc: 0.7400
# Epoch 21/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.1798 - acc: 0.9261 - val_loss: 0.5349 - val_acc: 0.7600
# Epoch 22/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.1354 - acc: 0.9648 - val_loss: 0.6628 - val_acc: 0.7200
# Epoch 23/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.1035 - acc: 0.9577 - val_loss: 0.6658 - val_acc: 0.7100
# Epoch 24/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0773 - acc: 0.9824 - val_loss: 0.7881 - val_acc: 0.7100
# Epoch 25/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0807 - acc: 0.9859 - val_loss: 0.9237 - val_acc: 0.7000
# Epoch 26/200
# 284/284 [==============================] - 4s 13ms/step - loss: 0.0384 - acc: 1.0000 - val_loss: 1.0411 - val_acc: 0.7100
# Epoch 27/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0217 - acc: 1.0000 - val_loss: 1.2521 - val_acc: 0.6900
# Epoch 28/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0129 - acc: 1.0000 - val_loss: 1.0147 - val_acc: 0.7200
# Epoch 29/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.9808 - val_acc: 0.7100
# Epoch 30/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 1.1272 - val_acc: 0.7200
# Epoch 31/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 1.1877 - val_acc: 0.7100
# Epoch 32/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 1.2165 - val_acc: 0.7200
# Epoch 33/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.2537 - val_acc: 0.7100
# Epoch 34/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 1.2649 - val_acc: 0.7200
# Epoch 35/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.2423 - val_acc: 0.7100
# Epoch 36/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.3731 - val_acc: 0.7100
# Epoch 37/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.2752 - val_acc: 0.7100
# Epoch 38/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.2711 - val_acc: 0.7000
# Epoch 39/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.2931 - val_acc: 0.7100
# Epoch 40/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.3302 - val_acc: 0.7200
# Epoch 41/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.3732 - val_acc: 0.7200
# Epoch 42/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.3226 - val_acc: 0.7000
# Epoch 43/200
# 284/284 [==============================] - 3s 12ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.4366 - val_acc: 0.7100
# Epoch 44/200
# 284/284 [==============================] - 4s 12ms/step - loss: 9.8895e-04 - acc: 1.0000 - val_loss: 1.4095 - val_acc: 0.7200
# Epoch 45/200
# 284/284 [==============================] - 3s 12ms/step - loss: 8.5290e-04 - acc: 1.0000 - val_loss: 1.4036 - val_acc: 0.7200
# Epoch 46/200
# 284/284 [==============================] - 3s 12ms/step - loss: 7.9055e-04 - acc: 1.0000 - val_loss: 1.4668 - val_acc: 0.7100
# Epoch 47/200
# 284/284 [==============================] - 3s 12ms/step - loss: 7.4102e-04 - acc: 1.0000 - val_loss: 1.4732 - val_acc: 0.7200
# Epoch 48/200
# 284/284 [==============================] - 3s 12ms/step - loss: 6.9546e-04 - acc: 1.0000 - val_loss: 1.4637 - val_acc: 0.7200
# Epoch 49/200
# 284/284 [==============================] - 3s 12ms/step - loss: 6.2841e-04 - acc: 1.0000 - val_loss: 1.4374 - val_acc: 0.7200
# Epoch 50/200
# 284/284 [==============================] - 3s 12ms/step - loss: 5.6917e-04 - acc: 1.0000 - val_loss: 1.4932 - val_acc: 0.7200
# Epoch 51/200
# 284/284 [==============================] - 3s 12ms/step - loss: 5.3581e-04 - acc: 1.0000 - val_loss: 1.4422 - val_acc: 0.7300
# Epoch 52/200
# 284/284 [==============================] - 3s 12ms/step - loss: 5.0902e-04 - acc: 1.0000 - val_loss: 1.5409 - val_acc: 0.7100
# Epoch 53/200
# 284/284 [==============================] - 3s 12ms/step - loss: 5.0726e-04 - acc: 1.0000 - val_loss: 1.4995 - val_acc: 0.7200
# Epoch 54/200
# 284/284 [==============================] - 4s 13ms/step - loss: 4.4143e-04 - acc: 1.0000 - val_loss: 1.5181 - val_acc: 0.7200
# Epoch 55/200
# 284/284 [==============================] - 3s 12ms/step - loss: 4.0721e-04 - acc: 1.0000 - val_loss: 1.5103 - val_acc: 0.7200
# Epoch 56/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.9373e-04 - acc: 1.0000 - val_loss: 1.5416 - val_acc: 0.7200
# Epoch 57/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.6741e-04 - acc: 1.0000 - val_loss: 1.5783 - val_acc: 0.7200
# Epoch 58/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.3722e-04 - acc: 1.0000 - val_loss: 1.5347 - val_acc: 0.7200
# Epoch 59/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.2067e-04 - acc: 1.0000 - val_loss: 1.5254 - val_acc: 0.7200
# Epoch 60/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.9896e-04 - acc: 1.0000 - val_loss: 1.5857 - val_acc: 0.7200
# Epoch 61/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.8289e-04 - acc: 1.0000 - val_loss: 1.5798 - val_acc: 0.7200
# Epoch 62/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.7032e-04 - acc: 1.0000 - val_loss: 1.5780 - val_acc: 0.7200
# Epoch 63/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.4957e-04 - acc: 1.0000 - val_loss: 1.5834 - val_acc: 0.7200
# Epoch 64/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.3297e-04 - acc: 1.0000 - val_loss: 1.5380 - val_acc: 0.7000
# Epoch 65/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.3221e-04 - acc: 1.0000 - val_loss: 1.6485 - val_acc: 0.7200
# Epoch 66/200
# 284/284 [==============================] - 3s 11ms/step - loss: 2.1176e-04 - acc: 1.0000 - val_loss: 1.6038 - val_acc: 0.7300
# Epoch 67/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.9923e-04 - acc: 1.0000 - val_loss: 1.6700 - val_acc: 0.7200
# Epoch 68/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.9334e-04 - acc: 1.0000 - val_loss: 1.6614 - val_acc: 0.7200
# Epoch 69/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.7956e-04 - acc: 1.0000 - val_loss: 1.6441 - val_acc: 0.7300
# Epoch 70/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.6857e-04 - acc: 1.0000 - val_loss: 1.6686 - val_acc: 0.7200
# Epoch 71/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1
# Epoch 94/200
# 284/284 [==============================] - 4s 14ms/step - loss: 4.8926e-05 - acc: 1.0000 - val_loss: 1.8952 - val_acc: 0.7200
# Epoch 95/200
# 284/284 [==============================] - 4s 13ms/step - loss: 5.2178e-05 - acc: 1.0000 - val_loss: 1.8079 - val_acc: 0.7100
# Epoch 96/200
# 284/284 [==============================] - 4s 14ms/step - loss: 4.5933e-05 - acc: 1.0000 - val_loss: 1.8587 - val_acc: 0.7300
# Epoch 97/200
# 284/284 [==============================] - 3s 12ms/step - loss: 4.3758e-05 - acc: 1.0000 - val_loss: 1.8206 - val_acc: 0.7100
# Epoch 98/200
# 284/284 [==============================] - 3s 12ms/step - loss: 4.5191e-05 - acc: 1.0000 - val_loss: 1.8716 - val_acc: 0.7200
# Epoch 99/200
# 284/284 [==============================] - 3s 12ms/step - loss: 4.1308e-05 - acc: 1.0000 - val_loss: 1.8349 - val_acc: 0.7100
# Epoch 100/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.8320e-05 - acc: 1.0000 - val_loss: 1.8453 - val_acc: 0.7100
# Epoch 101/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.6712e-05 - acc: 1.0000 - val_loss: 1.9076 - val_acc: 0.7200
# Epoch 102/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.5479e-05 - acc: 1.0000 - val_loss: 1.8785 - val_acc: 0.7100
# Epoch 103/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.4408e-05 - acc: 1.0000 - val_loss: 1.8902 - val_acc: 0.7300
# Epoch 104/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.1907e-05 - acc: 1.0000 - val_loss: 1.8951 - val_acc: 0.7200
# Epoch 105/200
# 284/284 [==============================] - 3s 12ms/step - loss: 3.0107e-05 - acc: 1.0000 - val_loss: 1.9066 - val_acc: 0.7200
# Epoch 106/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.9190e-05 - acc: 1.0000 - val_loss: 1.9150 - val_acc: 0.7300
# Epoch 107/200
# 284/284 [==============================] - 4s 13ms/step - loss: 2.7493e-05 - acc: 1.0000 - val_loss: 1.9226 - val_acc: 0.7200
# Epoch 108/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.6579e-05 - acc: 1.0000 - val_loss: 1.9524 - val_acc: 0.7200
# Epoch 109/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.5516e-05 - acc: 1.0000 - val_loss: 1.9473 - val_acc: 0.7300
# Epoch 110/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.4081e-05 - acc: 1.0000 - val_loss: 1.9400 - val_acc: 0.7300
# Epoch 111/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.3423e-05 - acc: 1.0000 - val_loss: 1.9674 - val_acc: 0.7300
# Epoch 112/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.2532e-05 - acc: 1.0000 - val_loss: 1.9355 - val_acc: 0.7100
# Epoch 113/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.1433e-05 - acc: 1.0000 - val_loss: 1.9151 - val_acc: 0.7100
# Epoch 114/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.0853e-05 - acc: 1.0000 - val_loss: 1.9653 - val_acc: 0.7200
# Epoch 115/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.9922e-05 - acc: 1.0000 - val_loss: 2.0274 - val_acc: 0.7200
# Epoch 116/200
# 284/284 [==============================] - 4s 14ms/step - loss: 1.8772e-05 - acc: 1.0000 - val_loss: 2.0023 - val_acc: 0.7300
# Epoch 117/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.7690e-05 - acc: 1.0000 - val_loss: 2.0084 - val_acc: 0.7300
# Epoch 118/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.7205e-05 - acc: 1.0000 - val_loss: 2.0133 - val_acc: 0.7300
# Epoch 119/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1
200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.2264e-06 - acc: 1.0000 - val_loss: 2.1960 - val_acc: 0.7200
# Epoch 167/200
# 284/284 [==============================] - 4s 13ms/step - loss: 2.1999e-06 - acc: 1.0000 - val_loss: 2.2279 - val_acc: 0.7100
# Epoch 168/200
# 284/284 [==============================] - 3s 12ms/step - loss: 2.1101e-06 - acc: 1.0000 - val_loss: 2.2458 - val_acc: 0.7100
# Epoch 169/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.9898e-06 - acc: 1.0000 - val_loss: 2.2442 - val_acc: 0.7100
# Epoch 170/200
# 284/284 [==============================] - 4s 13ms/step - loss: 1.8834e-06 - acc: 1.0000 - val_loss: 2.2504 - val_acc: 0.7100
# Epoch 171/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.8135e-06 - acc: 1.0000 - val_loss: 2.2605 - val_acc: 0.7200
# Epoch 172/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.7944e-06 - acc: 1.0000 - val_loss: 2.2763 - val_acc: 0.7200
# Epoch 173/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.7048e-06 - acc: 1.0000 - val_loss: 2.2765 - val_acc: 0.7200
# Epoch 174/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.6322e-06 - acc: 1.0000 - val_loss: 2.2962 - val_acc: 0.7300
# Epoch 175/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.5848e-06 - acc: 1.0000 - val_loss: 2.2791 - val_acc: 0.7200
# Epoch 176/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.5491e-06 - acc: 1.0000 - val_loss: 2.2675 - val_acc: 0.7100
# Epoch 177/200
# 284/284 [==============================] - 4s 12ms/step - loss: 1.4303e-06 - acc: 1.0000 - val_loss: 2.2948 - val_acc: 0.7200
# Epoch 178/200
# 284/284 [==============================] - 4s 12ms/step - loss: 1.4108e-06 - acc: 1.0000 - val_loss: 2.2817 - val_acc: 0.7100
# Epoch 179/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.3312e-06 - acc: 1.0000 - val_loss: 2.2958 - val_acc: 0.7200
# Epoch 180/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.2702e-06 - acc: 1.0000 - val_loss: 2.2874 - val_acc: 0.7100
# Epoch 181/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.2477e-06 - acc: 1.0000 - val_loss: 2.3005 - val_acc: 0.7200
# Epoch 182/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.1642e-06 - acc: 1.0000 - val_loss: 2.3311 - val_acc: 0.7200
# Epoch 183/200
# 284/284 [==============================] - 3s 11ms/step - loss: 1.1449e-06 - acc: 1.0000 - val_loss: 2.2949 - val_acc: 0.7100
# Epoch 184/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.0781e-06 - acc: 1.0000 - val_loss: 2.3218 - val_acc: 0.7200
# Epoch 185/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.0939e-06 - acc: 1.0000 - val_loss: 2.2840 - val_acc: 0.7200
# Epoch 186/200
# 284/284 [==============================] - 3s 12ms/step - loss: 1.0313e-06 - acc: 1.0000 - val_loss: 2.3097 - val_acc: 0.7100
# Epoch 187/200
# 284/284 [==============================] - 4s 12ms/step - loss: 9.6900e-07 - acc: 1.0000 - val_loss: 2.3223 - val_acc: 0.7200
# Epoch 188/200
# 284/284 [==============================] - 3s 12ms/step - loss: 9.2261e-07 - acc: 1.0000 - val_loss: 2.3126 - val_acc: 0.7100
# Epoch 189/200
# 284/284 [==============================] - 3s 12ms/step - loss: 9.0561e-07 - acc: 1.0000 - val_loss: 2.3413 - val_acc: 0.7200
# Epoch 190/200
# 284/284 [==============================] - 3s 12ms/step - loss: 8.5273e-07 - acc: 1.0000 - val_loss: 2.3142 - val_acc: 0.7200
# Epoch 191/200
# 284/284 [==============================] - 3s 12ms/step - loss: 8.3510e-07 - acc: 1.0000 - val_loss: 2.3380 - val_acc: 0.7200
# Epoch 192/200
# 284/284 [==============================] - 3s 12ms/step - loss: 8.0571e-07 - acc: 1.0000 - val_loss: 2.3375 - val_acc: 0.7100
# Epoch 193/200
# 284/284 [==============================] - 3s 12ms/step - loss: 7.8137e-07 - acc: 1.0000 - val_loss: 2.3626 - val_acc: 0.7200
# Epoch 194/200
# 284/284 [==============================] - 3s 12ms/step - loss: 7.4653e-07 - acc: 1.0000 - val_loss: 2.3362 - val_acc: 0.7200
# Epoch 195/200
# 284/284 [==============================] - 4s 12ms/step - loss: 7.0875e-07 - acc: 1.0000 - val_loss: 2.3422 - val_acc: 0.7200
# Epoch 196/200
# 284/284 [==============================] - 4s 13ms/step - loss: 6.9994e-07 - acc: 1.0000 - val_loss: 2.3380 - val_acc: 0.7200
# Epoch 197/200
# 284/284 [==============================] - 3s 12ms/step - loss: 6.6866e-07 - acc: 1.0000 - val_loss: 2.3611 - val_acc: 0.7200
# Epoch 198/200
# 284/284 [==============================] - 4s 13ms/step - loss: 6.5901e-07 - acc: 1.0000 - val_loss: 2.3704 - val_acc: 0.7200
# Epoch 199/200
# 284/284 [==============================] - 3s 12ms/step - loss: 6.2354e-07 - acc: 1.0000 - val_loss: 2.3646 - val_acc: 0.7100
# Epoch 200/200
# 284/284 [==============================] - 4s 13ms/step - loss: 5.8891e-07 - acc: 1.0000 - val_loss: 2.3708 - val_acc: 0.7100

# %%
accuracy
# Out:
# 0.70999999999999996

# %%
model.save_weights("weight.hdf5")

# %% [markdown]
# ### predict

# %%
def EmotionPredictor(files):
    fig = plt.figure()
    ax = fig.add_subplot(111)
        
    fig.show()
    fig.canvas.draw()
    
    
    data, fs = librosa.load(files)

    n    = data.size

    EffectiveInx= np.argwhere(data > 0.001)
    Effective   = data[EffectiveInx]
    n           = Effective.size
    Effective   = np.reshape(Effective, [n])
        
    Effective_stretch = librosa.effects.time_stretch(Effective, n / fs)
    S = librosa.feature.melspectrogram(Effective_stretch, sr=fs, n_mels=128)
    log_S = librosa.logamplitude(S, ref_power=np.max)
    log_S = log_S[:, range(44)]
        
    ax.clear()
    specshow(log_S, sr=fs, x_axis='time', y_axis='mel')
    fig.canvas.draw()
    plt.tight_layout()
                
    log_S = np.reshape(log_S, [1, 128, 44, 1])

    log_S = log_S.astype('float32')
    log_S /= 80

    predict = model.predict(log_S)
    if (np.argmax(predict, axis=1)==[1]):
        print("You Are Happy!")
    elif (np.argmax(predict, axis=1)==[0]):
        print("You Are Sad..")

# %%
os.chdir("/Users/hyunwoogu/Dropbox/2018MARG/Emotion Recognition/Emotional Speech Recognition/melspec_detection")

# %%
EmotionPredictor("HD5_P_05.wav")
# Out:
# /Users/hyunwoogu/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# You Are Sad..
